# %% [markdown]
# ### MCP协议开启AI员工互联网时代
# - 1、Agent互联网发展史
# - 2、互联网 vs Agent互联网变迁
# - 3、Agent互联网时代来临
# - 4、用户实操通过agent浏览器使用AI员工
# - 5、agent浏览器和AI员工未来预测

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 安装 tavily
#
# ```powershell
# $env:TAVILY_API_KEY="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"; npx -y tavily-mcp@0.1.3
# ```

# %% [markdown]
# ![image.png](attachment:image.png)
